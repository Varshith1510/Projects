# %% [markdown]
# #### **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Varshith\Desktop\Mini Project\Match Analysis.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Varshith/Desktop/Mini%20Project/Match%20Analysis.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Varshith/Desktop/Mini%20Project/Match%20Analysis.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/Varshith/Desktop/Mini%20Project/Match%20Analysis.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# #### **Reading Data**

# %%
df = pd.read_csv('IPL Matches.csv')
ball = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv')
ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193468 entries, 0 to 193467
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   inning            193468 non-null  int64
#  2   over              193468 non-null  int64
#  3   ball              193468 non-null  int64
#  4   batsman           193468 non-null  object
#  5   non_striker       193468 non-null  object
#  6   bowler            193468 non-null  object
#  7   batsman_runs      193468 non-null  int64
#  8   extra_runs        193468 non-null  int64
#  9   total_runs        193468 non-null  int64
#  10  non_boundary      193468 non-null  int64
#  11  is_wicket         193468 non-null  int64
#  12  dismissal_kind    9495 non-null    object
#  13  player_dismissed  9495 non-null    object
#  14  fielder           6784 non-null    object
#  15  extras_type       10233 non-null   object
# ...

# %% [markdown]
# #### **Data Preprocessing**

# %%
matches = df.copy()
matches.drop(columns = ['neutral_venue','method'],inplace = True)
matches.dropna(subset = ['result'],inplace=True)
matches.rename(columns={'id':'Match No','date':'Date','player_of_match':'Man of the match','venue':'Venue','team1':'Home Team',
                    'team2':'Away Team','toss_winner':'Toss Winner','toss_decision':'Toss Decision','winner':'Winner',
                    'result':'Result','result_margin':'Result Margin','eliminator':'Super Over','umpire1':'Umpire 1',
                    'umpire2':'Umpire 2'},inplace = True)
matches.reset_index(inplace = True)

# %%
matches["Loser"] = "\0"
for i in range(len(df1)):
    if matches.loc[i,'Winner'] == matches.loc[i,'Home Team']:
        matches.loc[i,'Loser'] = matches.loc[i,'Away Team']
    else:
        matches.loc[i,'Loser'] = matches.loc[i,'Home Team']

# %%
Match_no = [i for i in range(1,813)]
matches['Match No'] = Match_no
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Varshith\Desktop\Mini Project\Match Analysis.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Varshith/Desktop/Mini%20Project/Match%20Analysis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> Match_no = [i for i in range(1,813)]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Varshith/Desktop/Mini%20Project/Match%20Analysis.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> matches['Match No'] = Match_no
#
# NameError: name 'matches' is not defined

# %%
matches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Varshith\Desktop\Mini Project\Match Analysis.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Varshith/Desktop/Mini%20Project/Match%20Analysis.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> matches
#
# NameError: name 'matches' is not defined

# %%
matches['season'] = 0
c=0
for i in matches['Date']:
    a = i.split('-')
    matches["season"].iloc[c]=a[0]
    c+=1
matches
# Out:
# C:\Users\Varshith\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#      index  Match No        Date Man of the match  \
# 0        0         1  2008-04-18      BB McCullum
# 1        1         2  2008-04-19       MEK Hussey
# 2        2         3  2008-04-19      MF Maharoof
# 3        3         4  2008-04-20       MV Boucher
# 4        4         5  2008-04-20        DJ Hussey
# ..     ...       ...         ...              ...
# 807    811       808  2020-09-28   AB de Villiers
# 808    812       809  2020-11-05        JJ Bumrah
# 809    813       810  2020-11-06    KS Williamson
# 810    814       811  2020-11-08       MP Stoinis
# 811    815       812  2020-11-10         TA Boult
#
# ...

# %%
matches['Man of the match'].max()
# Out:
# 'Z Khan'

# %%
matches['Venue'].max()
# Out:
# 'Wankhede Stadium'

# %%
matches['Winner'].max()
# Out:
# 'Sunrisers Hyderabad'

# %%
matches['Loser'].max()
# Out:
# 'Sunrisers Hyderabad'

# %%
matches.to_csv('IPL Matches cleaned.csv',index=False,encoding = 'utf-8')

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             812 non-null    int64
#  1   Match No          812 non-null    int64
#  2   Date              812 non-null    object
#  3   Man of the match  812 non-null    object
#  4   Venue             812 non-null    object
#  5   Home Team         812 non-null    object
#  6   Away Team         812 non-null    object
#  7   Toss Winner       812 non-null    object
#  8   Toss Decision     812 non-null    object
#  9   Winner            812 non-null    object
#  10  Result            812 non-null    object
#  11  Result Margin     799 non-null    float64
#  12  Super Over        812 non-null    object
#  13  Umpire 1          812 non-null    object
#  14  Umpire 2          812 non-null    object
#  15  Loser             812 non-null    object
# ...

# %%
cleaned = pd.read_csv("IPL Matches cleaned.csv")

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             812 non-null    int64
#  1   Match No          812 non-null    int64
#  2   Date              812 non-null    object
#  3   Man of the match  812 non-null    object
#  4   Venue             812 non-null    object
#  5   Home Team         812 non-null    object
#  6   Away Team         812 non-null    object
#  7   Toss Winner       812 non-null    object
#  8   Toss Decision     812 non-null    object
#  9   Winner            812 non-null    object
#  10  Result            812 non-null    object
#  11  Result Margin     799 non-null    float64
#  12  Super Over        812 non-null    object
#  13  Umpire 1          812 non-null    object
#  14  Umpire 2          812 non-null    object
#  15  Loser             812 non-null    object
# ...

# %%
cleaned.head(10)
# Out:
#    index  Match No        Date Man of the match  \
# 0      0         1  2008-04-18      BB McCullum
# 1      1         2  2008-04-19       MEK Hussey
# 2      2         3  2008-04-19      MF Maharoof
# 3      3         4  2008-04-20       MV Boucher
# 4      4         5  2008-04-20        DJ Hussey
# 5      5         6  2008-04-21        SR Watson
# 6      6         7  2008-04-22         V Sehwag
# 7      7         8  2008-04-23        ML Hayden
# 8      8         9  2008-04-24        YK Pathan
# 9      9        10  2008-04-25    KC Sangakkara
#
#                                         Venue                    Home Team  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# ...
